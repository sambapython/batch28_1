# %%
s="python program"
print s
print "s"
# Out:
# python program
# s

# %%
a='12'
print type(a)
# Out:
# <type 'str'>

# %%
print a
# Out:
# 12

# %%
print "a"
# Out:
# a

# %%
s="python program"
a=s
b="s"
print b
print a
# Out:
# s
# python program

# %%
len(s)
# Out:
# 14

# %%
s
# Out:
# 'python program'

# %%
s[0]
# Out:
# 'p'

# %%
s[10]
# Out:
# 'g'

# %%
s[13]
# Out:
# 'm'

# %%
s[15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-69004e346f3a> in <module>()
# ----> 1 s[15]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'python program'

# %%
s[0]+s[1]+s[2]
# Out:
# 'pyt'

# %%
s[0]
# Out:
# 'p'

# %%
s[0:3]
# Out:
# 'pyt'

# %%
s[3]
# Out:
# 'h'

# %%
s
# Out:
# 'python program'

# %%
s[0:5]
# Out:
# 'pytho'

# %%
s[-1]
# Out:
# 'm'

# %%
s[-2]
# Out:
# 'a'

# %%
s[-13]
# Out:
# 'y'

# %%
s[-14]
# Out:
# 'p'

# %%
s[-15]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-e74a0a94e582> in <module>()
# ----> 1 s[-15]
#
# IndexError: string index out of range

# %%
s
# Out:
# 'python program'

# %%
s[0:5]
# Out:
# 'pytho'

# %%
s[:5]
# Out:
# 'pytho'

# %%
s[3:6]
# Out:
# 'hon'

# %%
s[3:]
# Out:
# 'hon program'

# %%
s
# Out:
# 'python program'

# %%
s[1:10]
# Out:
# 'ython pro'

# %%
s[1:10:2]
# Out:
# 'yhnpo'

# %%
s[:]
# Out:
# 'python program'

# %%
s[1:10]
# Out:
# 'ython pro'

# %%
s[10:1]
# Out:
# ''

# %%
s[10:1:-1]
# Out:
# 'gorp noht'

# %%
s[1:10:10]
# Out:
# 'y'

# %%
s[1:5:-1]
# Out:
# ''

# %%
s[1:10:10]
# Out:
# 'y'

# %%
s
# Out:
# 'python program'

# %%
s[::-1]
# Out:
# 'margorp nohtyp'

# %%
s[::2]
# Out:
# 'pto rga'

# %%
s[::-2]
# Out:
# 'mropnhy'

# %%
s
# Out:
# 'python program'

# %%
s[0]
# Out:
# 'p'

# %%
s[0:20]
# Out:
# 'python program'

# %%
s[20:30]
# Out:
# ''

# %%
s[30]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-b2e512f7a342> in <module>()
# ----> 1 s[30]
#
# IndexError: string index out of range

# %%
s[30:]
# Out:
# ''

# %%
s[30:10:-1]
# Out:
# 'mar'

# %%
s
# Out:
# 'python program'

# %%
a=10
b=20
print a==b
# Out:
# False

# %%
a=s

# %%
a
# Out:
# 'python program'

# %%
a=z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-b3f40aad0c59> in <module>()
# ----> 1 a=z
#
# NameError: name 'z' is not defined

# %%
a="z"

# %%
a=10

# %%
a=z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-b3f40aad0c59> in <module>()
# ----> 1 a=z
#
# NameError: name 'z' is not defined

# %%
a=python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-ef502d63e904> in <module>()
# ----> 1 a=python
#
# NameError: name 'python' is not defined

# %%
a=true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-0834b8a3a65c> in <module>()
# ----> 1 a=true
#
# NameError: name 'true' is not defined

# %%
a=True

# %%
type(a)
# Out:
# bool

# %%
a="True"
type(a)
# Out:
# str

# %%
a=True

# %%
type(a)
# Out:
# bool

# %%
a=False
type(a)
# Out:
# bool

# %%
a=None
type(a)
# Out:
# NoneType

# %%
int(None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-3f3b1d3c7325> in <module>()
# ----> 1 int(None)
#
# TypeError: int() argument must be a string or a number, not 'NoneType'

# %%
str(None)
# Out:
# 'None'

# %%
True=10

# %%
a=True

# %%
print a
# Out:
# 10

# %%
del True

# %%
print True
# Out:
# True

# %%
a=10
b=10

# %%
print a==b
print a is b
# Out:
# True
# True

# %%
a=1000
b=1000
print a==b
print a is b
# Out:
# True
# False

# %%
a=1000
b=a
print a==b
print a is b
# Out:
# True
# True

# %%
a=10
b=20
c=a
d=10

# %%
print a
# Out:
# 10

# %%
print c
# Out:
# 10

# %%
print id(a),id(c)
# Out:
# 31948976 31948976

# %%
a=1000
b=2000
c=a
d=1000

# %%
a="sdsggdfgdfhdhghgfj fgjhjhgjkhgkhjkjhlhjlkl"
b="sdsggdfgdfhdhghgfj fgjhjhgjkhgkhjkjhlhjlkl"
print id(a),id(b)
# Out:
# 140485351204784 140485351205264

# %%
a="python program"
b="python program"
print id(a),id(b)
# Out:
# 140485360259904 140485360259960

# %%
a="pythonprogram"
b="pythonprogram"
print id(a),id(b)
# Out:
# 140485360259624 140485360259624

# %%
a="python program"
b=a
print id(a),id(b)
# Out:
# 140485360260800 140485360260800

# %%
a=10
b=10
print a==b
print a is b
# Out:
# True
# True

# %%
a=1000
b=1000
print a==b
print a is b
# Out:
# True
# False

# %%
a=1000
b=a
print a==b
print a is b
# Out:
# True
# True

# %%
a=[1,2,3,4]

# %%
del a

# %%
print a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-9d7b17ad5387> in <module>()
# ----> 1 print a
#
# NameError: name 'a' is not defined

# %%
a=10
b=a

# %%
del a

# %%
print b
# Out:
# 10

# %%
a=20

# %%
print id(a)
# Out:
# 31948736

# %%
del a

# %%
print id(20)
# Out:
# 31948736

# %%
b=20

# %%
print id(b)
# Out:
# 31948736

# %%
a=10
b=20

# %%
print a==b
print a>b
print a<b
print a>=b
print a<=b
print a is b
# Out:
# False
# False
# True
# False
# True
# False

# %%
a=10
b=10
print a==b
# Out:
# True

# %%
a=10
b="10"
print a==b
# Out:
# False

# %%
a=10
b="1"
print a>b
# Out:
# False

# %%
a=1000
b="1"
print a>b
# Out:
# False

# %%
a="1000"
b="2"
print a>b
# Out:
# False

# %%
#'cat',"apple","banana" alpha "apple", "banana", cat
# 4 6 1 2 8, ascend
